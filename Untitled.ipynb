# %%
import pandas as pd

# %%
df=pd.read_csv("Span_new.csv")

# %%
df
# Out:
#        Unnamed: 0      ID        make    model  months_old  power gear_type  \
# 0               0   97860     Porsche      911       240.0  210.0    manual
# 1               1   27821        Ford  Mustang        54.0  487.0    manual
# 2               2   97801     Porsche      911       358.0  220.0    manual
# 3               3   98251     Porsche      911        14.0  368.0    manual
# 4               4   98250     Porsche      911         3.0  515.0   unknown
# ...           ...     ...         ...      ...         ...    ...       ...
# 92380       93986   38173        Opel    Astra       275.0   52.0    manual
# 92381       93987   57303  Volkswagen     Polo       232.0   37.0    manual
# 92382       93988   14541         Bmw      320       186.0  125.0    manual
# 92383       93989  103604        Seat   Toledo       276.0   66.0    manual
# 92384       93990   99672        Seat  Cordoba       232.0   81.0    manual
#
#       fuel_type       kms   price     age
# ...

# %%
df.plot(kind="bar")
